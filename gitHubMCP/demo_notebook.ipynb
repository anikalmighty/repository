# %% [markdown]
# # GitHub MCP Demo Notebook
#
# This notebook provides a lightweight walkthrough of the local demo layout. Use GitHub Copilot Chat and GitHub MCP tools to extend this demo in the repository.

# %%
from pathlib import Path

demo_folder = Path(__file__).resolve().parent
print('Demo folder:', demo_folder)
print('Files:')
for path in sorted(demo_folder.iterdir()):
    if path.is_file():
        print('-', path.name)

# %% [markdown]
# ## How to extend this demo
#
# - Use Copilot Chat to create a new file in `gitHubMCP`
# - Ask the assistant to summarize the current repository state
# - Run `demo.py` to verify the local demo layout
# - Use an MCP branch or issue tool to document changes
